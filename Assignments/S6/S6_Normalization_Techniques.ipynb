# %% [markdown]
# <a href="https://colab.research.google.com/github/amanjain487/tsai-eva6/blob/main/Assignments/S6/S6_Normalization_Techniques.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Libraries

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from __future__ import print_function
import numpy as np
import torch
import torch.optim as optim
import torch.nn.functional as F
from torchvision import datasets, transforms
from torch.optim.lr_scheduler import StepLR,OneCycleLR

from torchsummary import summary

# %matplotlib inline
import matplotlib.pyplot as plt


import sys
import os

py_file_location = '/content/drive/MyDrive/Colab Notebooks/'
sys.path.append(os.path.abspath(py_file_location))

import model
from model import Net

# %%
# !pip install torchsummary
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
print(device)
# Out:
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.7/dist-packages (1.5.1)
# cuda

# %% [markdown]
# # Split Dataset into Train set and Test set

# %%
train_set = datasets.MNIST('/content/drive/MyDrive/Colab Notebooks/mnist_data/', 
                   train=True, 
                   download=True,
                   transform=transforms.Compose([
                                       transforms.RandomRotation((-7.5, 7.5), fill=(1,)),
                                       transforms.ToTensor(),
                                       transforms.Normalize((0.1307,), (0.3081,)) 
                                       # The mean and std have to be sequences (e.g., tuples), therefore you should add a comma after the values. 
                                       ]))


test_set = datasets.MNIST('/content/drive/MyDrive/Colab Notebooks/mnist_data/', 
                   train=False, 
                   download=True,
                   transform=transforms.Compose([
                                       transforms.ToTensor(),
                                       transforms.Normalize((0.1307,), (0.3081,))
                                       ]))

# %% [markdown]
# # Create Data Loaders for Train and Test set

# %%
torch.manual_seed(1)
if use_cuda:
    torch.cuda.manual_seed(1)

batch_size=128

kwargs = {'num_workers': 2, 'pin_memory': True} if use_cuda else {}


train_loader = torch.utils.data.DataLoader(train_set, batch_size=batch_size, shuffle=True, **kwargs)

test_loader = torch.utils.data.DataLoader(test_set, batch_size=batch_size, shuffle=True, **kwargs)

# %% [markdown]
# # Define Train and Test Functions

# %%
lambda_l1 = 0.0001

def train(model, device, train_loader, optimizer, epoch, l1_loss):
    training_losses = []
    training_accuracy = []
    model.train()
    correct = 0
    processed = 0
    # lambda_l1 = 0.0001
    total_loss = 0
    for data, target in train_loader:
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = F.nll_loss(output, target)
        if l1_loss:
          l1 = 0
          for p in model.parameters():
            l1 = l1 + p.abs().sum()
          loss = loss + lambda_l1 * l1
        
        total_loss += loss
        loss.backward()
        optimizer.step()
        predictions = output.argmax(dim=1, keepdim=True)
        correct += predictions.eq(target.view_as(predictions)).sum().item()
        processed += len(data)
    training_losses.append(total_loss)
    training_accuracy.append(100*correct/processed)
    print('Loss = ', loss)
    if l1_loss:
      print('L1 = ', l1)
    print('Train set: Accuracy={:0.1f}'.format(100*correct/processed))
    return training_losses, training_accuracy



def test(model, device, test_loader):
    testing_losses = []
    testing_accuracy = []
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item()
            predictions = output.argmax(dim=1, keepdim=True)
            correct += predictions.eq(target.view_as(predictions)).sum().item()

    test_loss /= len(test_loader.dataset)
    testing_losses.append(test_loss)

    print('Test set: Average loss: {:.4f}, Accuracy: {}/{} ({:.1f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    testing_accuracy.append(100. * correct / len(test_loader.dataset))
    return testing_losses, testing_accuracy
  
def eval(model, test_loader):
  model.eval()
  test_loss = 0.0
  correct = 0
  im_pred = {'Wrong': []}
  i = 1
  plt_dt = dict()
  with torch.no_grad():
      for data, target in test_loader:
          if (len(im_pred['Wrong'])<20):
              data, target = data.to(device), target.to(device)
              output = model(data)
              test_loss += F.nll_loss(output, target, reduction='sum').item()  # sum up batch loss
              pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
              correct += pred.eq(target.view_as(pred)).sum().item()
              i+=1
              plt_dt['Input'], plt_dt['target'], plt_dt['pred'] = data.to('cpu'), target.to('cpu'), pred.to('cpu').view(-1,)

              for id in range(len(data)):
                  if plt_dt['target'][id] != plt_dt['pred'][id]:
                      im_pred['Wrong'] = im_pred['Wrong']+ [{'Image':data[id],'pred':pred[id],'actual' : target[id]}]
  
  plt.figure(figsize=(14,14)) 
  for i in range(20):
      plt.subplot(4,5,i+1)  
      pixels = np.array(im_pred['Wrong'][i]['Image'].cpu() , dtype='uint8')

      # Reshape the array into 28 x 28 array (2-dimensional array)
      pixels = pixels.reshape((28, 28))

      # Plot
      plt.title('Actual Value is {label}\n Predicted Value is {pred}'.format(label=im_pred['Wrong'][i]['actual'].cpu(), pred =im_pred['Wrong'][i]['pred'].cpu()[0]), color='r')
      plt.imshow(pixels, cmap='gray')

  plt.show()

# %% [markdown]
# *   Model Initialization and Summary - Print the model parameters and output shape at each layer by giving dummy input to torchsummary.
# *   Train and Test the Model - Initialize the Optimizers, loss, use LR Scheduling etc and execute the training Loop and collect loss and accuracy for further plotting the graphs.
#
# *   Evaluate the results.

# %%
# will be used while plotting graphs
training_losses_group = []
testing_losses_group = []
training_accuracy_group = []
testing_accuracy_group = []

model_group = Net("group").to(device)
print(summary(model_group, input_size=(1, 28, 28)))
optimizer_group = optim.SGD(model_group.parameters(), lr=0.01, momentum=0.9)
scheduler_group = StepLR(optimizer_group, step_size=6, gamma=0.1)

for epoch in range(1, 26):
    print("EPOCH:", epoch, "LR = ", scheduler_group.get_lr())
    training_l_g, training_a_g = train(model_group, device, train_loader, optimizer_group, epoch, l1_loss= True)
    print("training_l_g: ",training_l_g)
    testing_l_g, testing_a_g = test(model_group, device, test_loader)
    scheduler_group.step()
    training_losses_group.extend(training_l_g)
    # print("training_losses_group: ",training_losses_group)
    testing_losses_group.extend(testing_l_g)
    # print("testing_losses_group: ",testing_losses_group)
    training_accuracy_group.append(training_a_g)
    testing_accuracy_group.append(testing_a_g)

eval(model_group, test_loader)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 28, 28]             288
#          GroupNorm-2           [-1, 32, 28, 28]              64
#            Dropout-3           [-1, 32, 28, 28]               0
#               ReLU-4           [-1, 32, 28, 28]               0
#             Conv2d-5           [-1, 10, 28, 28]             320
#             Conv2d-6           [-1, 10, 28, 28]             900
#          GroupNorm-7           [-1, 10, 28, 28]              20
#            Dropout-8           [-1, 10, 28, 28]               0
#               ReLU-9           [-1, 10, 28, 28]               0
#         MaxPool2d-10           [-1, 10, 14, 14]               0
#            Conv2d-11           [-1, 10, 12, 12]             900
#         GroupNorm-12           [-1, 10, 12, 12]              20
#           Dropout-13           [-1, 10, 12, 12]               0
#              ReLU-14           [-1, 10, 12, 12]               0
#            Conv2d-15           [-1, 10, 10, 10]             900
#         GroupNorm-16           [-1, 10, 10, 10]              20
#              ReLU-17           [-1, 10, 10, 10]               0
#            Conv2d-18             [-1, 10, 8, 8]             900
#         GroupNorm-19             [-1, 10, 8, 8]              20
#           Dropout-20             [-1, 10, 8, 8]               0
#              ReLU-21             [-1, 10, 8, 8]               0
#            Conv2d-22             [-1, 16, 6, 6]           1,440
#         GroupNorm-23             [-1, 16, 6, 6]              32
#           Dropout-24             [-1, 16, 6, 6]               0
#              ReLU-25             [-1, 16, 6, 6]               0
#            Conv2d-26             [-1, 10, 4, 4]           1,440
#         GroupNorm-27             [-1, 10, 4, 4]              20
#           Dropout-28             [-1, 10, 4, 4]               0
#              ReLU-29             [-1, 10, 4, 4]               0
#         AvgPool2d-30             [-1, 10, 1, 1]               0
#            Linear-31                   [-1, 10]             100
# ================================================================
# Total params: 7,384
# Trainable params: 7,384
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 1.19
# Params size (MB): 0.03
# Estimated Total Size (MB): 1.22
# ----------------------------------------------------------------
# None
# EPOCH: 1 LR =  [0.01]
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:370: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   "please use `get_last_lr()`.", UserWarning)
# Loss =  tensor(0.2149, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(602.2270, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=81.0
# training_l_g:  [tensor(359.3862, device='cuda:0', grad_fn=<AddBackward0>)]
# Test set: Average loss: 0.1734, Accuracy: 9577/10000 (95.8%)
#
# EPOCH: 2 LR =  [0.01]
# Loss =  tensor(0.2603, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(623.6110, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=96.8
# training_l_g:  [tensor(86.3335, device='cuda:0', grad_fn=<AddBackward0>)]
# Test set: Average loss: 0.0663, Accuracy: 9815/10000 (98.2%)
#
# EPOCH: 3 LR =  [0.01]
# Loss =  tensor(0.1042, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(630.9833, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=97.6
# training_l_g:  [tensor(70.1655, device='cuda:0', grad_fn=<AddBackward0>)]
# Test set: Average loss: 0.0548, Accuracy: 9849/10000 (98.5%)
#
# EPOCH: 4 LR =  [0.01]
# Loss =  tensor(0.1876, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(631.7328, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=98.0
# training_l_g:  [tensor(62.2634, device='cuda:0', grad_fn=<AddBackward0>)]
# Test set: Average loss: 0.0661, Accuracy: 9809/10000 (98.1%)
#
# EPOCH: 5 LR =  [0.01]
# Loss =  tensor(0.1291, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(629.3203, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=98.2
# training_l_g:  [tensor(58.6856, device='cuda:0', grad_fn=<AddBackward0>)]
# Test set: Average loss: 0.0472, Accuracy: 9869/10000 (98.7%)
#
# EPOCH: 6 LR =  [0.01]
# Loss =  tensor(0.1363, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(625.4080, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=98.4
# training_l_g:  [tensor(56.2717, device='cuda:0', grad_fn=<AddBackward0>)]
# Test set: Average loss: 0.0446, Accuracy: 9871/10000 (98.7%)
#
# EPOCH: 7 LR =  [0.0001]
# Loss =  tensor(0.1319, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(622.6790, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=98.9
# training_l_g:  [tensor(47.0723, device='cuda:0', grad_fn=<AddBackward0>)]
# Test set: Average loss: 0.0275, Accuracy: 9922/10000 (99.2%)
#
# EPOCH: 8 LR =  [0.001]
# Loss =  tensor(0.0777, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(620.1018, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=99.0
# training_l_g:  [tensor(45.8875, device='cuda:0', grad_fn=<AddBackward0>)]
# Test set: Average loss: 0.0280, Accuracy: 9926/10000 (99.3%)
#
# EPOCH: 9 LR =  [0.001]
# Loss =  tensor(0.0752, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(617.5808, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=99.1
# training_l_g:  [tensor(44.6878, device='cuda:0', grad_fn=<AddBackward0>)]
# Test set: Average loss: 0.0263, Accuracy: 9925/10000 (99.2%)
#
# EPOCH: 10 LR =  [0.001]
# Loss =  tensor(0.0785, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(615.1925, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=99.1
# training_l_g:  [tensor(44.5443, device='cuda:0', grad_fn=<AddBackward0>)]
# Test set: Average loss: 0.0260, Accuracy: 9926/10000 (99.3%)
#
# EPOCH: 11 LR =  [0.001]
# Loss =  tensor(0.0979, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(612.7659, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=99.1
# training_l_g:  [tensor(43.9689, device='cuda:0', grad_fn=<AddBackward0>)]
# Test set: Average loss: 0.0266, Accuracy: 9924/10000 (99.2%)
#
# EPOCH: 12 LR =  [0.001]
# Loss =  tensor(0.0856, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(610.3791, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=99.1
# training_l_g:  [tensor(43.5875, device='cuda:0', grad_fn=<AddBackward0>)]
# Test set: Average loss: 0.0247, Accuracy: 9930/10000 (99.3%)
#
# EPOCH: 13 LR =  [1e-05]
# Loss =  tensor(0.0746, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(610.0957, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=99.2
# training_l_g:  [tensor(42.4682, device='cuda:0', grad_fn=<AddBackward0>)]
# Test set: Average loss: 0.0237, Accuracy: 9935/10000 (99.3%)
#
# EPOCH: 14 LR =  [0.0001]
# Loss =  tensor(0.0781, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(609.8309, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=99.1
# training_l_g:  [tensor(42.7978, device='cuda:0', grad_fn=<AddBackward0>)]
# Test set: Average loss: 0.0240, Accuracy: 9936/10000 (99.4%)
#
# EPOCH: 15 LR =  [0.0001]
# Loss =  tensor(0.1266, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(609.5593, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=99.2
# training_l_g:  [tensor(42.5493, device='cuda:0', grad_fn=<AddBackward0>)]
# Test set: Average loss: 0.0239, Accuracy: 9934/10000 (99.3%)
#
# EPOCH: 16 LR =  [0.0001]
# Loss =  tensor(0.1357, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(609.3011, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=99.2
# training_l_g:  [tensor(42.6784, device='cuda:0', grad_fn=<AddBackward0>)]
# Test set: Average loss: 0.0238, Accuracy: 9934/10000 (99.3%)
#
# EPOCH: 17 LR =  [0.0001]
# Loss =  tensor(0.0751, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(609.0454, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=99.2
# training_l_g:  [tensor(42.4015, device='cuda:0', grad_fn=<AddBackward0>)]
# Test set: Average loss: 0.0239, Accuracy: 9933/10000 (99.3%)
#
# EPOCH: 18 LR =  [0.0001]
# Loss =  tensor(0.0789, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(608.7870, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=99.2
# training_l_g:  [tensor(42.5662, device='cuda:0', grad_fn=<AddBackward0>)]
# Test set: Average loss: 0.0239, Accuracy: 9933/10000 (99.3%)
#
# EPOCH: 19 LR =  [1.0000000000000002e-06]
# Loss =  tensor(0.0669, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(608.7567, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=99.2
# training_l_g:  [tensor(42.5037, device='cuda:0', grad_fn=<AddBackward0>)]
# Test set: Average loss: 0.0238, Accuracy: 9933/10000 (99.3%)
#
# EPOCH: 20 LR =  [1e-05]
# Loss =  tensor(0.1175, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(608.7278, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=99.2
# training_l_g:  [tensor(42.3194, device='cuda:0', grad_fn=<AddBackward0>)]
# Test set: Average loss: 0.0238, Accuracy: 9933/10000 (99.3%)
#
# EPOCH: 21 LR =  [1e-05]
# Loss =  tensor(0.0796, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(608.7007, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=99.2
# training_l_g:  [tensor(42.3432, device='cuda:0', grad_fn=<AddBackward0>)]
# Test set: Average loss: 0.0238, Accuracy: 9933/10000 (99.3%)
#
# EPOCH: 22 LR =  [1e-05]
# Loss =  tensor(0.0803, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(608.6747, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=99.2
# training_l_g:  [tensor(42.4329, device='cuda:0', grad_fn=<AddBackward0>)]
# Test set: Average loss: 0.0238, Accuracy: 9933/10000 (99.3%)
#
# EPOCH: 23 LR =  [1e-05]
# Loss =  tensor(0.1075, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(608.6476, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=99.2
# training_l_g:  [tensor(42.4428, device='cuda:0', grad_fn=<AddBackward0>)]
# Test set: Average loss: 0.0238, Accuracy: 9932/10000 (99.3%)
#
# EPOCH: 24 LR =  [1e-05]
# Loss =  tensor(0.0792, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(608.6225, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=99.2
# training_l_g:  [tensor(42.2176, device='cuda:0', grad_fn=<AddBackward0>)]
# Test set: Average loss: 0.0238, Accuracy: 9932/10000 (99.3%)
#
# EPOCH: 25 LR =  [1.0000000000000002e-07]
# Loss =  tensor(0.0798, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(608.6197, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=99.2
# training_l_g:  [tensor(42.2456, device='cuda:0', grad_fn=<AddBackward0>)]
# Test set: Average loss: 0.0238, Accuracy: 9932/10000 (99.3%)

# %%
# will be used while plotting graphs
training_losses_layer = []
testing_losses_layer = []
training_accuracy_layer = []
testing_accuracy_layer = []


model_layer = Net("layer").to(device)
print(summary(model_layer, input_size=(1, 28, 28)))
optimizer_layer = optim.SGD(model_layer.parameters(), lr=0.01, momentum=0.9, weight_decay=0.001)
scheduler_layer = StepLR(optimizer_layer, step_size=6, gamma=0.1)

for epoch in range(1, 26):
    print("EPOCH:", epoch, "LR = ", scheduler_layer.get_lr())
    training_l_l, training_a_l = train(model_layer, device, train_loader, optimizer_layer, epoch, l1_loss= False)
    testing_l_l, testing_a_l = test(model_layer, device, test_loader)
    scheduler_layer.step()
    training_losses_layer.extend(training_l_l)
    testing_losses_layer.extend(testing_l_l)
    training_accuracy_layer.extend(training_a_l)
    testing_accuracy_layer.extend(testing_a_l)

eval(model_layer, test_loader)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 28, 28]             288
#          GroupNorm-2           [-1, 32, 28, 28]              64
#            Dropout-3           [-1, 32, 28, 28]               0
#               ReLU-4           [-1, 32, 28, 28]               0
#             Conv2d-5           [-1, 10, 28, 28]             320
#             Conv2d-6           [-1, 10, 28, 28]             900
#          GroupNorm-7           [-1, 10, 28, 28]              20
#            Dropout-8           [-1, 10, 28, 28]               0
#               ReLU-9           [-1, 10, 28, 28]               0
#         MaxPool2d-10           [-1, 10, 14, 14]               0
#            Conv2d-11           [-1, 10, 12, 12]             900
#         GroupNorm-12           [-1, 10, 12, 12]              20
#           Dropout-13           [-1, 10, 12, 12]               0
#              ReLU-14           [-1, 10, 12, 12]               0
#            Conv2d-15           [-1, 10, 10, 10]             900
#         GroupNorm-16           [-1, 10, 10, 10]              20
#              ReLU-17           [-1, 10, 10, 10]               0
#            Conv2d-18             [-1, 10, 8, 8]             900
#         GroupNorm-19             [-1, 10, 8, 8]              20
#           Dropout-20             [-1, 10, 8, 8]               0
#              ReLU-21             [-1, 10, 8, 8]               0
#            Conv2d-22             [-1, 16, 6, 6]           1,440
#         GroupNorm-23             [-1, 16, 6, 6]              32
#           Dropout-24             [-1, 16, 6, 6]               0
#              ReLU-25             [-1, 16, 6, 6]               0
#            Conv2d-26             [-1, 10, 4, 4]           1,440
#         GroupNorm-27             [-1, 10, 4, 4]              20
#           Dropout-28             [-1, 10, 4, 4]               0
#              ReLU-29             [-1, 10, 4, 4]               0
#         AvgPool2d-30             [-1, 10, 1, 1]               0
#            Linear-31                   [-1, 10]             100
# ================================================================
# Total params: 7,384
# Trainable params: 7,384
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 1.19
# Params size (MB): 0.03
# Estimated Total Size (MB): 1.22
# ----------------------------------------------------------------
# None
# EPOCH: 1 LR =  [0.01]
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:370: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   "please use `get_last_lr()`.", UserWarning)
# Loss =  tensor(0.1857, device='cuda:0', grad_fn=<NllLossBackward>)
# Train set: Accuracy=75.5
# Test set: Average loss: 0.1698, Accuracy: 9572/10000 (95.7%)
#
# EPOCH: 2 LR =  [0.01]
# Loss =  tensor(0.1620, device='cuda:0', grad_fn=<NllLossBackward>)
# Train set: Accuracy=96.4
# Test set: Average loss: 0.1029, Accuracy: 9718/10000 (97.2%)
#
# EPOCH: 3 LR =  [0.01]
# Loss =  tensor(0.0555, device='cuda:0', grad_fn=<NllLossBackward>)
# Train set: Accuracy=97.1
# Test set: Average loss: 0.0763, Accuracy: 9796/10000 (98.0%)
#
# EPOCH: 4 LR =  [0.01]
# Loss =  tensor(0.0300, device='cuda:0', grad_fn=<NllLossBackward>)
# Train set: Accuracy=97.5
# Test set: Average loss: 0.0671, Accuracy: 9810/10000 (98.1%)
#
# EPOCH: 5 LR =  [0.01]
# Loss =  tensor(0.0606, device='cuda:0', grad_fn=<NllLossBackward>)
# Train set: Accuracy=97.9
# Test set: Average loss: 0.0588, Accuracy: 9837/10000 (98.4%)
#
# EPOCH: 6 LR =  [0.01]
# Loss =  tensor(0.0626, device='cuda:0', grad_fn=<NllLossBackward>)
# Train set: Accuracy=97.9
# Test set: Average loss: 0.0484, Accuracy: 9861/10000 (98.6%)
#
# EPOCH: 7 LR =  [0.0001]
# Loss =  tensor(0.0318, device='cuda:0', grad_fn=<NllLossBackward>)
# Train set: Accuracy=98.7
# Test set: Average loss: 0.0403, Accuracy: 9877/10000 (98.8%)
#
# EPOCH: 8 LR =  [0.001]
# Loss =  tensor(0.1004, device='cuda:0', grad_fn=<NllLossBackward>)
# Train set: Accuracy=98.8
# Test set: Average loss: 0.0396, Accuracy: 9898/10000 (99.0%)
#
# EPOCH: 9 LR =  [0.001]
# Loss =  tensor(0.0207, device='cuda:0', grad_fn=<NllLossBackward>)
# Train set: Accuracy=98.8
# Test set: Average loss: 0.0382, Accuracy: 9898/10000 (99.0%)
#
# EPOCH: 10 LR =  [0.001]
# Loss =  tensor(0.0544, device='cuda:0', grad_fn=<NllLossBackward>)
# Train set: Accuracy=98.8
# Test set: Average loss: 0.0384, Accuracy: 9895/10000 (99.0%)
#
# EPOCH: 11 LR =  [0.001]
# Loss =  tensor(0.0357, device='cuda:0', grad_fn=<NllLossBackward>)
# Train set: Accuracy=98.8
# Test set: Average loss: 0.0368, Accuracy: 9899/10000 (99.0%)
#
# EPOCH: 12 LR =  [0.001]
# Loss =  tensor(0.0688, device='cuda:0', grad_fn=<NllLossBackward>)
# Train set: Accuracy=98.9
# Test set: Average loss: 0.0381, Accuracy: 9898/10000 (99.0%)
#
# EPOCH: 13 LR =  [1e-05]
# Loss =  tensor(0.0513, device='cuda:0', grad_fn=<NllLossBackward>)
# Train set: Accuracy=98.9
# Test set: Average loss: 0.0363, Accuracy: 9906/10000 (99.1%)
#
# EPOCH: 14 LR =  [0.0001]
# Loss =  tensor(0.0629, device='cuda:0', grad_fn=<NllLossBackward>)
# Train set: Accuracy=99.0
# Test set: Average loss: 0.0359, Accuracy: 9908/10000 (99.1%)
#
# EPOCH: 15 LR =  [0.0001]
# Loss =  tensor(0.0519, device='cuda:0', grad_fn=<NllLossBackward>)
# Train set: Accuracy=99.0
# Test set: Average loss: 0.0359, Accuracy: 9907/10000 (99.1%)
#
# EPOCH: 16 LR =  [0.0001]
# Loss =  tensor(0.0445, device='cuda:0', grad_fn=<NllLossBackward>)
# Train set: Accuracy=99.0
# Test set: Average loss: 0.0357, Accuracy: 9905/10000 (99.0%)
#
# EPOCH: 17 LR =  [0.0001]
# Loss =  tensor(0.0168, device='cuda:0', grad_fn=<NllLossBackward>)
# Train set: Accuracy=99.0
# Test set: Average loss: 0.0358, Accuracy: 9909/10000 (99.1%)
#
# EPOCH: 18 LR =  [0.0001]
# Loss =  tensor(0.0255, device='cuda:0', grad_fn=<NllLossBackward>)
# Train set: Accuracy=99.0
# Test set: Average loss: 0.0355, Accuracy: 9908/10000 (99.1%)
#
# EPOCH: 19 LR =  [1.0000000000000002e-06]
# Loss =  tensor(0.0325, device='cuda:0', grad_fn=<NllLossBackward>)
# Train set: Accuracy=99.0
# Test set: Average loss: 0.0355, Accuracy: 9908/10000 (99.1%)
#
# EPOCH: 20 LR =  [1e-05]
# Loss =  tensor(0.0705, device='cuda:0', grad_fn=<NllLossBackward>)
# Train set: Accuracy=99.0
# Test set: Average loss: 0.0355, Accuracy: 9908/10000 (99.1%)
#
# EPOCH: 21 LR =  [1e-05]
# Loss =  tensor(0.0116, device='cuda:0', grad_fn=<NllLossBackward>)
# Train set: Accuracy=99.0
# Test set: Average loss: 0.0355, Accuracy: 9908/10000 (99.1%)
#
# EPOCH: 22 LR =  [1e-05]
# Loss =  tensor(0.0531, device='cuda:0', grad_fn=<NllLossBackward>)
# Train set: Accuracy=99.0
# Test set: Average loss: 0.0355, Accuracy: 9908/10000 (99.1%)
#
# EPOCH: 23 LR =  [1e-05]
# Loss =  tensor(0.0133, device='cuda:0', grad_fn=<NllLossBackward>)
# Train set: Accuracy=99.0
# Test set: Average loss: 0.0355, Accuracy: 9908/10000 (99.1%)
#
# EPOCH: 24 LR =  [1e-05]
# Loss =  tensor(0.0780, device='cuda:0', grad_fn=<NllLossBackward>)
# Train set: Accuracy=99.0
# Test set: Average loss: 0.0355, Accuracy: 9908/10000 (99.1%)
#
# EPOCH: 25 LR =  [1.0000000000000002e-07]
# Loss =  tensor(0.0559, device='cuda:0', grad_fn=<NllLossBackward>)
# Train set: Accuracy=99.0
# Test set: Average loss: 0.0355, Accuracy: 9908/10000 (99.1%)

# %%
# will be used while plotting graphs
training_losses_batch= []
testing_losses_batch = []
training_accuracy_batch = []
testing_accuracy_batch = []


model_batch = Net("batch").to(device)
print(summary(model_batch, input_size=(1, 28, 28)))
optimizer_batch = optim.SGD(model_batch.parameters(), lr=0.01, momentum=0.9, weight_decay=0.001)
scheduler_batch = StepLR(optimizer_batch, step_size=6, gamma=0.1)

for epoch in range(1, 26):
    print("EPOCH:", epoch, "LR = ", scheduler_batch.get_lr())
    training_l_b, training_a_b = train(model_batch, device, train_loader, optimizer_batch, epoch, l1_loss= True)
    testing_l_b, testing_a_b = test(model_batch, device, test_loader)
    scheduler_batch.step()
    training_losses_batch.extend(training_l_b)
    testing_losses_batch.extend(testing_l_b)
    training_accuracy_batch.extend(training_a_b)
    testing_accuracy_batch.extend(testing_a_b)

eval(model_batch, test_loader)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 28, 28]             288
#        BatchNorm2d-2           [-1, 32, 28, 28]              64
#            Dropout-3           [-1, 32, 28, 28]               0
#               ReLU-4           [-1, 32, 28, 28]               0
#             Conv2d-5           [-1, 10, 28, 28]             320
#             Conv2d-6           [-1, 10, 28, 28]             900
#        BatchNorm2d-7           [-1, 10, 28, 28]              20
#            Dropout-8           [-1, 10, 28, 28]               0
#               ReLU-9           [-1, 10, 28, 28]               0
#         MaxPool2d-10           [-1, 10, 14, 14]               0
#            Conv2d-11           [-1, 10, 12, 12]             900
#       BatchNorm2d-12           [-1, 10, 12, 12]              20
#           Dropout-13           [-1, 10, 12, 12]               0
#              ReLU-14           [-1, 10, 12, 12]               0
#            Conv2d-15           [-1, 10, 10, 10]             900
#       BatchNorm2d-16           [-1, 10, 10, 10]              20
#              ReLU-17           [-1, 10, 10, 10]               0
#            Conv2d-18             [-1, 10, 8, 8]             900
#       BatchNorm2d-19             [-1, 10, 8, 8]              20
#           Dropout-20             [-1, 10, 8, 8]               0
#              ReLU-21             [-1, 10, 8, 8]               0
#            Conv2d-22             [-1, 16, 6, 6]           1,440
#       BatchNorm2d-23             [-1, 16, 6, 6]              32
#           Dropout-24             [-1, 16, 6, 6]               0
#              ReLU-25             [-1, 16, 6, 6]               0
#            Conv2d-26             [-1, 10, 4, 4]           1,440
#       BatchNorm2d-27             [-1, 10, 4, 4]              20
#           Dropout-28             [-1, 10, 4, 4]               0
#              ReLU-29             [-1, 10, 4, 4]               0
#         AvgPool2d-30             [-1, 10, 1, 1]               0
#            Linear-31                   [-1, 10]             100
# ================================================================
# Total params: 7,384
# Trainable params: 7,384
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 1.19
# Params size (MB): 0.03
# Estimated Total Size (MB): 1.22
# ----------------------------------------------------------------
# None
# EPOCH: 1 LR =  [0.01]
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:370: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   "please use `get_last_lr()`.", UserWarning)
# Loss =  tensor(0.2151, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(536.5087, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=86.3
# Test set: Average loss: 0.0830, Accuracy: 9810/10000 (98.1%)
#
# EPOCH: 2 LR =  [0.01]
# Loss =  tensor(0.0770, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(517.3726, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=98.0
# Test set: Average loss: 0.0630, Accuracy: 9827/10000 (98.3%)
#
# EPOCH: 3 LR =  [0.01]
# Loss =  tensor(0.1173, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(496.5927, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=98.3
# Test set: Average loss: 0.0419, Accuracy: 9894/10000 (98.9%)
#
# EPOCH: 4 LR =  [0.01]
# Loss =  tensor(0.1558, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(475.3469, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=98.5
# Test set: Average loss: 0.0442, Accuracy: 9882/10000 (98.8%)
#
# EPOCH: 5 LR =  [0.01]
# Loss =  tensor(0.0814, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(456.0038, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=98.6
# Test set: Average loss: 0.0381, Accuracy: 9903/10000 (99.0%)
#
# EPOCH: 6 LR =  [0.01]
# Loss =  tensor(0.0735, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(439.7341, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=98.6
# Test set: Average loss: 0.0352, Accuracy: 9906/10000 (99.1%)
#
# EPOCH: 7 LR =  [0.0001]
# Loss =  tensor(0.0753, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(435.1053, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=99.0
# Test set: Average loss: 0.0237, Accuracy: 9942/10000 (99.4%)
#
# EPOCH: 8 LR =  [0.001]
# Loss =  tensor(0.0590, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(430.7059, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=99.2
# Test set: Average loss: 0.0228, Accuracy: 9939/10000 (99.4%)
#
# EPOCH: 9 LR =  [0.001]
# Loss =  tensor(0.0729, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(426.4869, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=99.2
# Test set: Average loss: 0.0230, Accuracy: 9937/10000 (99.4%)
#
# EPOCH: 10 LR =  [0.001]
# Loss =  tensor(0.0845, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(422.3393, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=99.2
# Test set: Average loss: 0.0228, Accuracy: 9942/10000 (99.4%)
#
# EPOCH: 11 LR =  [0.001]
# Loss =  tensor(0.0568, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(418.2793, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=99.2
# Test set: Average loss: 0.0218, Accuracy: 9942/10000 (99.4%)
#
# EPOCH: 12 LR =  [0.001]
# Loss =  tensor(0.0929, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(414.2572, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=99.2
# Test set: Average loss: 0.0220, Accuracy: 9938/10000 (99.4%)
#
# EPOCH: 13 LR =  [1e-05]
# Loss =  tensor(0.0953, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(413.7947, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=99.3
# Test set: Average loss: 0.0216, Accuracy: 9938/10000 (99.4%)
#
# EPOCH: 14 LR =  [0.0001]
# Loss =  tensor(0.0635, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(413.3596, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=99.3
# Test set: Average loss: 0.0214, Accuracy: 9941/10000 (99.4%)
#
# EPOCH: 15 LR =  [0.0001]
# Loss =  tensor(0.0736, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(412.9468, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=99.3
# Test set: Average loss: 0.0217, Accuracy: 9940/10000 (99.4%)
#
# EPOCH: 16 LR =  [0.0001]
# Loss =  tensor(0.0759, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(412.5284, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=99.3
# Test set: Average loss: 0.0216, Accuracy: 9939/10000 (99.4%)
#
# EPOCH: 17 LR =  [0.0001]
# Loss =  tensor(0.0815, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(412.0953, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=99.3
# Test set: Average loss: 0.0213, Accuracy: 9945/10000 (99.5%)
#
# EPOCH: 18 LR =  [0.0001]
# Loss =  tensor(0.0829, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(411.6814, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=99.3
# Test set: Average loss: 0.0216, Accuracy: 9941/10000 (99.4%)
#
# EPOCH: 19 LR =  [1.0000000000000002e-06]
# Loss =  tensor(0.0810, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(411.6363, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=99.3
# Test set: Average loss: 0.0218, Accuracy: 9946/10000 (99.5%)
#
# EPOCH: 20 LR =  [1e-05]
# Loss =  tensor(0.0686, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(411.5923, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=99.3
# Test set: Average loss: 0.0217, Accuracy: 9939/10000 (99.4%)
#
# EPOCH: 21 LR =  [1e-05]
# Loss =  tensor(0.0531, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(411.5473, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=99.3
# Test set: Average loss: 0.0214, Accuracy: 9943/10000 (99.4%)
#
# EPOCH: 22 LR =  [1e-05]
# Loss =  tensor(0.0518, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(411.5023, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=99.3
# Test set: Average loss: 0.0212, Accuracy: 9942/10000 (99.4%)
#
# EPOCH: 23 LR =  [1e-05]
# Loss =  tensor(0.0773, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(411.4589, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=99.3
# Test set: Average loss: 0.0216, Accuracy: 9942/10000 (99.4%)
#
# EPOCH: 24 LR =  [1e-05]
# Loss =  tensor(0.0633, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(411.4145, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=99.3
# Test set: Average loss: 0.0215, Accuracy: 9942/10000 (99.4%)
#
# EPOCH: 25 LR =  [1.0000000000000002e-07]
# Loss =  tensor(0.0579, device='cuda:0', grad_fn=<AddBackward0>)
# L1 =  tensor(411.4104, device='cuda:0', grad_fn=<AddBackward0>)
# Train set: Accuracy=99.3
# Test set: Average loss: 0.0213, Accuracy: 9943/10000 (99.4%)

# %% [markdown]
# ### Plotting Training Loss per Epoch

# %%
plt.rcParams['figure.figsize'] = [15, 6]

def plotting_curves(model1, model2, model3, legend, title):
  plt.plot(np.array(model1))
  plt.plot(np.array(model2), 'r')
  plt.plot(np.array(model3), 'g')
  plt.legend(legend)
  plt.title(title)

plotting_curves(training_losses_group, training_losses_layer, training_losses_batch, ['Group Normalization + L1', 'Layer Normalization + L2', 'Batch Normalization + L1 + L2'], 'Training Loss per Epoch')

# %% [markdown]
# ### Plotting Test Loss per Epoch

# %%
plotting_curves(testing_losses_group, testing_losses_layer, testing_losses_batch, ['Group Normalization + L1', 'Layer Normalization + L2', 'Batch Normalization + L1 + L2'], 'Test Loss per Epoch')

# %% [markdown]
# ### Plotting Test Accuracy per Epoch

# %%
plotting_curves(testing_accuracy_group, testing_accuracy_layer, testing_accuracy_batch, ['Group Normalization + L1', 'Layer Normalization + L2', 'Batch Normalization + L1 + L2'], 'Test Accuracy per Epoch')

# %% [markdown]
# ### Plotting Training Accuracy per Epoch

# %%
plotting_curves(training_accuracy_group, training_accuracy_layer, training_accuracy_batch, ['Group Normalization + L1', 'Layer Normalization + L2', 'Batch Normalization + L1 + L2'], 'Training Accuracy per Epoch')
