# %% [markdown]
# <a href="https://colab.research.google.com/github/amanjain487/tsai-eva6/blob/main/Assignments/S6/final_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import os

py_file_location = '/content/drive/MyDrive/Colab Notebooks/'
sys.path.append(os.path.abspath(py_file_location))

import model

# %%
model.main1('layer')
# Out:
# cuda
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 32, 28, 28]             288
#          LayerNorm-2           [-1, 32, 28, 28]          50,176
#            Dropout-3           [-1, 32, 28, 28]               0
#               ReLU-4           [-1, 32, 28, 28]               0
#             Conv2d-5           [-1, 10, 28, 28]             320
#             Conv2d-6           [-1, 10, 28, 28]             900
#          LayerNorm-7           [-1, 10, 28, 28]          15,680
#            Dropout-8           [-1, 10, 28, 28]               0
#               ReLU-9           [-1, 10, 28, 28]               0
#         MaxPool2d-10           [-1, 10, 14, 14]               0
#            Conv2d-11           [-1, 10, 12, 12]             900
#         LayerNorm-12           [-1, 10, 12, 12]           2,880
#           Dropout-13           [-1, 10, 12, 12]               0
# ...

# %%
model.main1('group')
# Out:
# cuda
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 32, 28, 28]             288
#          GroupNorm-2           [-1, 32, 28, 28]              64
#            Dropout-3           [-1, 32, 28, 28]               0
#               ReLU-4           [-1, 32, 28, 28]               0
#             Conv2d-5           [-1, 10, 28, 28]             320
#             Conv2d-6           [-1, 10, 28, 28]             900
#          GroupNorm-7           [-1, 10, 28, 28]              20
#            Dropout-8           [-1, 10, 28, 28]               0
#               ReLU-9           [-1, 10, 28, 28]               0
#         MaxPool2d-10           [-1, 10, 14, 14]               0
#            Conv2d-11           [-1, 10, 12, 12]             900
#         GroupNorm-12           [-1, 10, 12, 12]              20
#           Dropout-13           [-1, 10, 12, 12]               0
# ...

# %%
model.main1('batch')
# Out:
# cuda
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 32, 28, 28]             288
#        BatchNorm2d-2           [-1, 32, 28, 28]              64
#            Dropout-3           [-1, 32, 28, 28]               0
#               ReLU-4           [-1, 32, 28, 28]               0
#             Conv2d-5           [-1, 10, 28, 28]             320
#             Conv2d-6           [-1, 10, 28, 28]             900
#        BatchNorm2d-7           [-1, 10, 28, 28]              20
#            Dropout-8           [-1, 10, 28, 28]               0
#               ReLU-9           [-1, 10, 28, 28]               0
#         MaxPool2d-10           [-1, 10, 14, 14]               0
#            Conv2d-11           [-1, 10, 12, 12]             900
#       BatchNorm2d-12           [-1, 10, 12, 12]              20
#           Dropout-13           [-1, 10, 12, 12]               0
# ...

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [15, 6]

def training_curves(model1, model2, model3, legend, title):
  plt.plot(np.array(model1))
  plt.plot(np.array(model2), 'r')
  plt.plot(np.array(model3), 'g')
  plt.legend(legend)
  plt.title(title)

training_curves(model.training_losses_group, model.training_losses_layer, model.training_losses_batch, ['Group Normalization + L1', 'Layer Normalization + L2', 'Batch Normalization + L1 + L2'], 'Training Loss per Epoch')

# %%
plt.rcParams['figure.figsize'] = [15, 6]

def training_curves(model1, model2, model3, legend, title):
  plt.plot(np.array(model1))
  plt.plot(np.array(model2), 'r')
  plt.plot(np.array(model3), 'g')
  plt.legend(legend)
  plt.title(title)

training_curves(model.testing_losses_group, model.testing_losses_layer, model.testing_losses_batch, ['Group Normalization + L1', 'Layer Normalization + L2', 'Batch Normalization + L1 + L2'], 'Test Loss per Epoch')

# %%
plt.rcParams['figure.figsize'] = [15, 6]

def training_curves(model1, model2, model3, legend, title):
  plt.plot(np.array(model1))
  plt.plot(np.array(model2), 'r')
  plt.plot(np.array(model3), 'g')
  plt.legend(legend)
  plt.title(title)

training_curves(model.testing_accuracy_group, model.testing_accuracy_layer, model.testing_accuracy_batch, ['Group Normalization + L1', 'Layer Normalization + L2', 'Batch Normalization + L1 + L2'], 'Test Accuracy per Epoch')

# %%
plt.rcParams['figure.figsize'] = [15, 6]

def training_curves(model1, model2, model3, legend, title):
  plt.plot(np.array(model1))
  plt.plot(np.array(model2), 'r')
  plt.plot(np.array(model3), 'g')
  plt.legend(legend)
  plt.title(title)

training_curves(model.training_accuracy_group, model.training_accuracy_layer, model.training_accuracy_batch, ['Group Normalization + L1', 'Layer Normalization + L2', 'Batch Normalization + L1 + L2'], 'Training Accuracy per Epoch')
